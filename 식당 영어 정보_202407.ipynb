# %%
import os
import time
import pandas as pd
import pymysql
import numpy as np
from haversine import haversine
from decimal import Decimal
from tqdm.auto import tqdm

def live_db_conn():
    """Live DB 접속 함수"""
    conn = pymysql.connect(
        host = "db-6j3k3.pub-cdb.ntruss.com", 
        user = "redtable",
        password = "fpemxpdlqmf5491!@#",
        autocommit = True, 
        cursorclass = pymysql.cursors.DictCursor, 
        db = "redtable2021")
    return conn


def dev_db_conn():
    """개발 DB 접속 함수"""
    conn = pymysql.connect(
        host = 'db-7ma06.pub-cdb.ntruss.com',
        user = 'redtable',
        password = 'fpemxpdlqmf5491!@#',
        autocommit = True,
        cursorclass = pymysql.cursors.DictCursor)
    return conn


def rt_db_conn():
    """빅데이터센터 DB 접속 함수"""
    conn = pymysql.connect(
        host = '220.95.212.6',
        user = 'red_dev_jiang',
        password = 'redtable211b',
        db = 'redtable_bigdata_center',
        autocommit = True,
        cursorclass= pymysql.cursors.DictCursor)
    conn.query("set character_set_connection=utf8;")
    conn.query("set character_set_server=utf8;")
    conn.query("set character_set_client=utf8;")
    conn.query("set character_set_results=utf8;")
    conn.query("set character_set_database=utf8;")
    return conn


file_path = os.path.join(os.environ["HOMEPATH"], "Downloads/")

# %% [markdown]
# # 식당 영어 정보
#
# # RT_RESTAURANT_EN_INFO_202407
#
# ## https://www.bigdata-culture.kr/bigdata/user/data_market/detail.do?id=f9b7e0c1-8af1-48ff-815e-ad3642597581

# %%
with rt_db_conn() as conn:
    sql = """
    SELECT TABLE_NAME, COLUMN_NAME, column_comment
    FROM information_schema.`COLUMNS`
    WHERE TABLE_NAME = 'RT_RESTAURANT_EN_INFO_202407'
    """
    columns = pd.read_sql(sql, conn)
    
# 컬럼명 가져오기
db_cols = ','.join(columns['COLUMN_NAME'])

# %%
# 라이브DB에서는 불필요한 것들을 분류하기 어렵고, 개발DB에서는 지하철 연결이 안되어있어서 나눠서 작업진행함.
with dev_db_conn() as conn:
    sql = """
    SELECT T5.EN AS 'CTY_NM', T3.SRC_ID AS 'RSTRNT_ID', T4.RSTR_NM AS 'RSTRNT_NM',
      IF(T4.LNNO_ADRES = '', NULL, T4.LNNO_ADRES) AS 'LNM_ADDR',
      IF(T4.RDNMADR = '', NULL, T4.RDNMADR) AS 'RDNMADR_NM',
      IF(T1.RSTR_TELNO = '', NULL, T1.RSTR_TELNO) AS 'RSTRNT_TEL_NO',
      '' AS 'SUBWAYST_NM', '' AS 'SUBWAYST_DSTNC_VALUE', T1.RSTR_LA AS 'RSTRNT_LA', T1.RSTR_LO AS 'RSTRNT_LO'
    FROM redtable01.RSTR T1
    INNER JOIN redtable01.RSTR_INDEX T2 ON T1.ID = T2.RSTR_ID
    INNER JOIN redtable01.RSTR_CONN T3 ON T2.RSTR_ID = T3.RSTR_ID
    INNER JOIN redtable01.RSTR_TRANSLATE T4 ON T3.RSTR_ID = T4.RSTR_ID
    INNER JOIN dictionary.shido T5 ON T1.AREA_NM_1 = T5.SHIDO_NM
    WHERE T2.IS_USE=1 AND T2.IS_OPEN=1 AND T3.SRC='live_db' AND T1.AREA_NM_1 IS NOT NULL AND T1.AREA_NM_1<>''
    AND T1.RSTR_NM IS NOT NULL AND T1.RSTR_NM<>'' AND T1.RSTR_NM NOT LIKE '%%？%%'
    AND T4.LANG_NM = 'EN'
    ORDER BY T3.SRC_ID ASC
    """
    df = pd.read_sql(sql, conn)

# %%
with live_db_conn() as conn:
    sql = f"""
    SELECT T1.store_id, T3.name, MIN(T1.distance) AS min_distance
    FROM redtable2021.store_landmark T1
    INNER JOIN redtable2021.landmark_master T2 ON T1.landmark_master_id = T2.id
    INNER JOIN redtable2021.landmark_translate T3 ON T2.id = T3.landmark_master_id
    WHERE T2.`type` = '지하철역' AND T3.lang = 'en' AND T1.store_id IN {tuple(df["RSTRNT_ID"].tolist())}
    GROUP BY T1.store_id
    """
    subway = pd.read_sql(sql, conn)

# %%
set_idx = subway.set_index("store_id")["name"].to_dict()
df["SUBWAYST_NM"] = df["RSTRNT_ID"].map(set_idx)

set_idx = subway.set_index("store_id")["min_distance"].to_dict()
df["SUBWAYST_DSTNC_VALUE"] = df["RSTRNT_ID"].map(set_idx)

# 결측치 및 불필요한 데이터 정리
df = df.fillna(np.nan)
df.replace({np.nan:None, '\\n':None}, inplace=True)

# %%
df
# Out:
#        CTY_NM  RSTRNT_ID                               RSTRNT_NM  \
# 0       Seoul      10012                         Myeongdongjeong
# 1       Seoul      10013                  Myeongdong Seoseogalbi
# 2       Seoul      10014                 BONGCHU BRAISED CHICKEN
# 3       Seoul      10016                    Myeongdong Hanu Bang
# 4       Seoul      10017                                Seolbing
# ...       ...        ...                                     ...
# 871168  Busan    1191094                            Hoesasikdang
# 871169  Daegu    1191095  Fresh Keteoring Mo Tonic Daegugongjang
# 871170  Busan    1628785                                 CHAORAN
# 871171  Busan    1628786                        YAKITORI Haegong
# 871172  Seoul    1631452                        Hansik Wangbijip
#
#                                            LNM_ADDR  \
# 0           60-3, Chungmuro 2(i)-ga, Jung-gu, Seoul
# 1           23, Myeong-dong 2(i)-ga, Jung-gu, Seoul
# 2          25-8, Chungmuro 1(il)-ga, Jung-gu, Seoul
# 3           199-56, Euljiro 2(i)-ga, Jung-gu, Seoul
# 4       33-43, Changcheon-dong, Seodaemun-gu, Seoul
# ...                                             ...
# 871168           1172, Jisa-dong, Gangseo-gu, Busan
# 871169      1095-11, Sindang-dong, Dalseo-gu, Daegu
# 871170          1829, Jung-dong, Haeundae-gu, Busan
# 871171         24-6, Millak-dong, Suyeong-gu, Busan
# 871172    52-5, Myeong-dong 2(i)-ga, Jung-gu, Seoul
#
#                                                RDNMADR_NM   RSTRNT_TEL_NO  \
# 0                        299, Samil-daero, Jung-gu, Seoul    02-3789-5130
# 1                35-10, Myeongdong 10-gil, Jung-gu, Seoul            None
# 2                  47, Myeongdong 8na-gil, Jung-gu, Seoul    02-3789-9381
# 3                  37-5, Myeongdong 9-gil, Jung-gu, Seoul    02-2267-8132
# 4                      23, Yonsei-ro, Seodaemun-gu, Seoul     02-325-8492
# ...                                                   ...             ...
# 871168            502, Gwahaksandan-ro, Gangseo-gu, Busan            None
# 871169                530, Dalseo-daero, Dalseo-gu, Daegu    053-382-3311
# 871170                30, Dalmaji-gil, Haeundae-gu, Busan  0507-1356-1253
# 871171  \t30-5, Millakbondong-ro 19beon-gil, Suyeong-g...  0507-1479-8334
# 871172               15, Myeongdong 6-gil, Jung-gu, Seoul     02-777-7004
#
#                     SUBWAYST_NM SUBWAYST_DSTNC_VALUE  RSTRNT_LA   RSTRNT_LO
# 0       Euljiro 1(il)ga Station               264.35  37.561532   126.98849
# 1       Euljiro 1(il)ga Station               185.92  37.562512  126.985993
# 2             City Hall Station               304.28  37.561065  126.982289
# 3               Jonggak Station               528.49  37.565386  126.983939
# 4               Sinchon Station               351.59  37.557762   126.93669
# ...                         ...                  ...        ...         ...
# 871168                     None                 None  35.150177   128.81681
# 871169                     None                 None  35.845846  128.493328
# 871170                     None                 None  35.159937  129.169813
# 871171                     None                 None  35.158234  129.127114
# 871172                     None                 None  37.562613  126.984479
#
# [871173 rows x 10 columns]

# %%
with rt_db_conn() as conn:
    with conn.cursor() as curs:
        sql = f"""
        INSERT IGNORE INTO redtable_bigdata_center.RT_RESTAURANT_EN_INFO_202407({db_cols})
        VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
        """
        val = df.apply(lambda row:(row["CTY_NM"], row["RSTRNT_ID"], row["RSTRNT_NM"], row["LNM_ADDR"],
                                  row["RDNMADR_NM"], row["RSTRNT_TEL_NO"], row["SUBWAYST_NM"], row["SUBWAYST_DSTNC_VALUE"],
                                  row["RSTRNT_LA"], row["RSTRNT_LO"]), axis=1).tolist()
        curs.executemany(sql, val)
